# %%
# %matplotlib inline
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import display

# %%
filename = 'Sessões com os membros 2022_1 (respostas).xlsx'
if filename in os.listdir():
    print(f'Found the file {filename}, ready to go!')
else:
    print(f'No file found with {filename} in directory {os.getcwd()}, have you downloaded the file?')
# Out:
# Não encontrei o arquivo Sessões com os membros 2022_1 (respostas).xlsx aqui no diretório /Users/enriccogemha/Developer/fox-baja-member-sessions, será que você não baixou o arquivo?

# %%
dataframe = pd.read_excel(filename, sheet_name = 'Respostas ao formulário 1')
dataframe
# Out:
#       Carimbo de data/hora                                     Nome  \
# 0  2022-04-26 14:08:20.009              Henrique Moura Costa Damico
# 1  2022-04-26 14:22:22.542             Gabriel Brunoro Motta Tumang
# 2  2022-04-26 14:34:21.765               Natan Kron Goldenberg Lewi
# 3  2022-04-26 14:44:50.577            Enzo Francisco Klann Fonteyne
# 4  2022-04-26 15:05:32.341        Maria Eduarda Matta Mercer Mourão
# 5  2022-04-26 15:12:16.352  José Edson Mendonça Ribeiro Lima Araújo
# 6  2022-04-27 10:01:48.624       Gustavo de Lorenzi Cancellier Katz
# 7  2022-04-28 14:14:26.825                            Daniel Parnes
# 8  2022-04-28 14:19:45.236                  Luano de Matos Sorpreso
# 9  2022-04-28 14:24:59.938          Lorena Barbosa Antunes da Silva
# 10 2022-04-28 14:32:36.050               Mateus Ruggero de Oliveira
# 11 2022-04-28 14:51:52.465                    André Mestriner Costa
# 12 2022-04-29 13:26:20.337                      Gabriel Esgaib Tess
# ...

# %%
questions = dataframe.head()

for row in dataframe.iterrows():
    
    with open('readme.txt', 'w') as f:
    file = open('devolutivas/', 'w')
    file.write('readme')
